# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import datetime

#Data file paths
application_path = "Data_Original/application_record.csv"
credit_path = "Data_Original/credit_record.csv"

#Read the data
application = pd.read_csv(application_path)
credit = pd.read_csv(credit_path)

#Combine the data into a single DataFrame
data_merge = pd.merge(application, credit, on = "ID")
#Display the data table for preview
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment      -12005          -4542
# 1             Civil marriage  Rented apartment      -12005          -4542
# 2             Civil marriage  Rented apartment      -12005          -4542
# 3             Civil marriage  Rented apartment      -12005          -4542
# 4             Civil marriage  Rented apartment      -12005          -4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment       -9188          -1193
# 777711  Single / not married  Rented apartment       -9188          -1193
# 777712  Single / not married  Rented apartment       -9188          -1193
# 777713  Single / not married  Rented apartment       -9188          -1193
# 777714  Single / not married  Rented apartment       -9188          -1193
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                1           0           0             NaN
# 3                1                1           0           0             NaN
# 4                1                1           0           0             NaN
# ...            ...              ...         ...         ...             ...
# 777710           1                0           0           0        Laborers
# 777711           1                0           0           0        Laborers
# 777712           1                0           0           0        Laborers
# 777713           1                0           0           0        Laborers
# 777714           1                0           0           0        Laborers
#
#         CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                   2.0               0      C
# 1                   2.0              -1      C
# 2                   2.0              -2      C
# 3                   2.0              -3      C
# 4                   2.0              -4      C
# ...                 ...             ...    ...
# 777710              1.0              -9      0
# 777711              1.0             -10      2
# 777712              1.0             -11      1
# 777713              1.0             -12      0
# 777714              1.0             -13      0
#
# [777715 rows x 20 columns]

# %%
#Dropping uneeded columns
drop_cols = ["FLAG_WORK_PHONE", "FLAG_PHONE","FLAG_EMAIL"]
data_merge.drop(drop_cols, axis = 1, inplace = True)
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment      -12005          -4542
# 1             Civil marriage  Rented apartment      -12005          -4542
# 2             Civil marriage  Rented apartment      -12005          -4542
# 3             Civil marriage  Rented apartment      -12005          -4542
# 4             Civil marriage  Rented apartment      -12005          -4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment       -9188          -1193
# 777711  Single / not married  Rented apartment       -9188          -1193
# 777712  Single / not married  Rented apartment       -9188          -1193
# 777713  Single / not married  Rented apartment       -9188          -1193
# 777714  Single / not married  Rented apartment       -9188          -1193
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                1             NaN              2.0               0      C
# 1                1             NaN              2.0              -1      C
# 2                1             NaN              2.0              -2      C
# 3                1             NaN              2.0              -3      C
# 4                1             NaN              2.0              -4      C
# ...            ...             ...              ...             ...    ...
# 777710           1        Laborers              1.0              -9      0
# 777711           1        Laborers              1.0             -10      2
# 777712           1        Laborers              1.0             -11      1
# 777713           1        Laborers              1.0             -12      0
# 777714           1        Laborers              1.0             -13      0
#
# [777715 rows x 17 columns]

# %%
#Filling certain blank results in our data
data_merge.loc[data_merge['NAME_INCOME_TYPE'] == 'Pensioner', 'OCCUPATION_TYPE'] = data_merge.loc[data_merge['NAME_INCOME_TYPE'] == 'Pensioner', 'OCCUPATION_TYPE'].fillna('Pensioner')
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment      -12005          -4542
# 1             Civil marriage  Rented apartment      -12005          -4542
# 2             Civil marriage  Rented apartment      -12005          -4542
# 3             Civil marriage  Rented apartment      -12005          -4542
# 4             Civil marriage  Rented apartment      -12005          -4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment       -9188          -1193
# 777711  Single / not married  Rented apartment       -9188          -1193
# 777712  Single / not married  Rented apartment       -9188          -1193
# 777713  Single / not married  Rented apartment       -9188          -1193
# 777714  Single / not married  Rented apartment       -9188          -1193
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                1             NaN              2.0               0      C
# 1                1             NaN              2.0              -1      C
# 2                1             NaN              2.0              -2      C
# 3                1             NaN              2.0              -3      C
# 4                1             NaN              2.0              -4      C
# ...            ...             ...              ...             ...    ...
# 777710           1        Laborers              1.0              -9      0
# 777711           1        Laborers              1.0             -10      2
# 777712           1        Laborers              1.0             -11      1
# 777713           1        Laborers              1.0             -12      0
# 777714           1        Laborers              1.0             -13      0
#
# [777715 rows x 17 columns]

# %%
#Converting negative numbers to positive numbers
neg_convert = ['DAYS_BIRTH', 'DAYS_EMPLOYED', 'MONTHS_BALANCE']
data_merge[neg_convert] = data_merge[neg_convert].abs()
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment       12005           4542
# 1             Civil marriage  Rented apartment       12005           4542
# 2             Civil marriage  Rented apartment       12005           4542
# 3             Civil marriage  Rented apartment       12005           4542
# 4             Civil marriage  Rented apartment       12005           4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment        9188           1193
# 777711  Single / not married  Rented apartment        9188           1193
# 777712  Single / not married  Rented apartment        9188           1193
# 777713  Single / not married  Rented apartment        9188           1193
# 777714  Single / not married  Rented apartment        9188           1193
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                1             NaN              2.0               0      C
# 1                1             NaN              2.0               1      C
# 2                1             NaN              2.0               2      C
# 3                1             NaN              2.0               3      C
# 4                1             NaN              2.0               4      C
# ...            ...             ...              ...             ...    ...
# 777710           1        Laborers              1.0               9      0
# 777711           1        Laborers              1.0              10      2
# 777712           1        Laborers              1.0              11      1
# 777713           1        Laborers              1.0              12      0
# 777714           1        Laborers              1.0              13      0
#
# [777715 rows x 17 columns]

# %%
#Replacing error values in our data
data_merge["DAYS_EMPLOYED"] = data_merge["DAYS_EMPLOYED"].replace(365243, 0)
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment       12005           4542
# 1             Civil marriage  Rented apartment       12005           4542
# 2             Civil marriage  Rented apartment       12005           4542
# 3             Civil marriage  Rented apartment       12005           4542
# 4             Civil marriage  Rented apartment       12005           4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment        9188           1193
# 777711  Single / not married  Rented apartment        9188           1193
# 777712  Single / not married  Rented apartment        9188           1193
# 777713  Single / not married  Rented apartment        9188           1193
# 777714  Single / not married  Rented apartment        9188           1193
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                1             NaN              2.0               0      C
# 1                1             NaN              2.0               1      C
# 2                1             NaN              2.0               2      C
# 3                1             NaN              2.0               3      C
# 4                1             NaN              2.0               4      C
# ...            ...             ...              ...             ...    ...
# 777710           1        Laborers              1.0               9      0
# 777711           1        Laborers              1.0              10      2
# 777712           1        Laborers              1.0              11      1
# 777713           1        Laborers              1.0              12      0
# 777714           1        Laborers              1.0              13      0
#
# [777715 rows x 17 columns]

# %%
#Looping through DAYS_EMPLOYED column to convert the numbers into a count of how many years old they are
for index,rows in data_merge.iterrows():
    data_merge.at[index, 'DAYS_BIRTH']/=365
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment   32.890411           4542
# 1             Civil marriage  Rented apartment   32.890411           4542
# 2             Civil marriage  Rented apartment   32.890411           4542
# 3             Civil marriage  Rented apartment   32.890411           4542
# 4             Civil marriage  Rented apartment   32.890411           4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment   25.172603           1193
# 777711  Single / not married  Rented apartment   25.172603           1193
# 777712  Single / not married  Rented apartment   25.172603           1193
# 777713  Single / not married  Rented apartment   25.172603           1193
# 777714  Single / not married  Rented apartment   25.172603           1193
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                1             NaN              2.0               0      C
# 1                1             NaN              2.0               1      C
# 2                1             NaN              2.0               2      C
# 3                1             NaN              2.0               3      C
# 4                1             NaN              2.0               4      C
# ...            ...             ...              ...             ...    ...
# 777710           1        Laborers              1.0               9      0
# 777711           1        Laborers              1.0              10      2
# 777712           1        Laborers              1.0              11      1
# 777713           1        Laborers              1.0              12      0
# 777714           1        Laborers              1.0              13      0
#
# [777715 rows x 17 columns]

# %%
#Casting DAYS_BIRTH column as integer
data_merge["DAYS_BIRTH"] = data_merge["DAYS_BIRTH"].astype(int)
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment          32           4542
# 1             Civil marriage  Rented apartment          32           4542
# 2             Civil marriage  Rented apartment          32           4542
# 3             Civil marriage  Rented apartment          32           4542
# 4             Civil marriage  Rented apartment          32           4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment          25           1193
# 777711  Single / not married  Rented apartment          25           1193
# 777712  Single / not married  Rented apartment          25           1193
# 777713  Single / not married  Rented apartment          25           1193
# 777714  Single / not married  Rented apartment          25           1193
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                1             NaN              2.0               0      C
# 1                1             NaN              2.0               1      C
# 2                1             NaN              2.0               2      C
# 3                1             NaN              2.0               3      C
# 4                1             NaN              2.0               4      C
# ...            ...             ...              ...             ...    ...
# 777710           1        Laborers              1.0               9      0
# 777711           1        Laborers              1.0              10      2
# 777712           1        Laborers              1.0              11      1
# 777713           1        Laborers              1.0              12      0
# 777714           1        Laborers              1.0              13      0
#
# [777715 rows x 17 columns]

# %%
#Filling any Null results in the OCCUPATION_TYPE column with Not Specified
data_merge['OCCUPATION_TYPE'] = data_merge['OCCUPATION_TYPE'].fillna("Not Specified")
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment          32           4542
# 1             Civil marriage  Rented apartment          32           4542
# 2             Civil marriage  Rented apartment          32           4542
# 3             Civil marriage  Rented apartment          32           4542
# 4             Civil marriage  Rented apartment          32           4542
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment          25           1193
# 777711  Single / not married  Rented apartment          25           1193
# 777712  Single / not married  Rented apartment          25           1193
# 777713  Single / not married  Rented apartment          25           1193
# 777714  Single / not married  Rented apartment          25           1193
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                1   Not Specified              2.0               0      C
# 1                1   Not Specified              2.0               1      C
# 2                1   Not Specified              2.0               2      C
# 3                1   Not Specified              2.0               3      C
# 4                1   Not Specified              2.0               4      C
# ...            ...             ...              ...             ...    ...
# 777710           1        Laborers              1.0               9      0
# 777711           1        Laborers              1.0              10      2
# 777712           1        Laborers              1.0              11      1
# 777713           1        Laborers              1.0              12      0
# 777714           1        Laborers              1.0              13      0
#
# [777715 rows x 17 columns]

# %%
#Looping through DAYS_EMPLOYED column to convert the numbers into a count of how many months
for index,rows in data_merge.iterrows():
    data_merge.at[index, 'DAYS_EMPLOYED']/=30.44
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment          32     149.211564
# 1             Civil marriage  Rented apartment          32     149.211564
# 2             Civil marriage  Rented apartment          32     149.211564
# 3             Civil marriage  Rented apartment          32     149.211564
# 4             Civil marriage  Rented apartment          32     149.211564
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment          25      39.191853
# 777711  Single / not married  Rented apartment          25      39.191853
# 777712  Single / not married  Rented apartment          25      39.191853
# 777713  Single / not married  Rented apartment          25      39.191853
# 777714  Single / not married  Rented apartment          25      39.191853
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                1   Not Specified              2.0               0      C
# 1                1   Not Specified              2.0               1      C
# 2                1   Not Specified              2.0               2      C
# 3                1   Not Specified              2.0               3      C
# 4                1   Not Specified              2.0               4      C
# ...            ...             ...              ...             ...    ...
# 777710           1        Laborers              1.0               9      0
# 777711           1        Laborers              1.0              10      2
# 777712           1        Laborers              1.0              11      1
# 777713           1        Laborers              1.0              12      0
# 777714           1        Laborers              1.0              13      0
#
# [777715 rows x 17 columns]

# %%
#Casting DAYS_EMPLOYED column as integer
data_merge["DAYS_EMPLOYED"] = data_merge["DAYS_EMPLOYED"].astype(int)
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment          32            149
# 1             Civil marriage  Rented apartment          32            149
# 2             Civil marriage  Rented apartment          32            149
# 3             Civil marriage  Rented apartment          32            149
# 4             Civil marriage  Rented apartment          32            149
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment          25             39
# 777711  Single / not married  Rented apartment          25             39
# 777712  Single / not married  Rented apartment          25             39
# 777713  Single / not married  Rented apartment          25             39
# 777714  Single / not married  Rented apartment          25             39
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                1   Not Specified              2.0               0      C
# 1                1   Not Specified              2.0               1      C
# 2                1   Not Specified              2.0               2      C
# 3                1   Not Specified              2.0               3      C
# 4                1   Not Specified              2.0               4      C
# ...            ...             ...              ...             ...    ...
# 777710           1        Laborers              1.0               9      0
# 777711           1        Laborers              1.0              10      2
# 777712           1        Laborers              1.0              11      1
# 777713           1        Laborers              1.0              12      0
# 777714           1        Laborers              1.0              13      0
#
# [777715 rows x 17 columns]

# %%
#Recategorising the STATUS column
data_merge["STATUS"] = data_merge["STATUS"].replace({"0": 'Minor Over',
                                                     "1": 'Minor Over',
                                                     "2": 'Minor Over',
                                                     "3": 'Minor Over',
                                                     "4": 'Minor Over',
                                                     "5": 'Major Over',
                                                     'C': 'Paid',
                                                     'X': 'No Loan Taken'})
data_merge
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0          Working               Higher education
# 1               427500.0          Working               Higher education
# 2               427500.0          Working               Higher education
# 3               427500.0          Working               Higher education
# 4               427500.0          Working               Higher education
# ...                  ...              ...                            ...
# 777710          112500.0          Working  Secondary / secondary special
# 777711          112500.0          Working  Secondary / secondary special
# 777712          112500.0          Working  Secondary / secondary special
# 777713          112500.0          Working  Secondary / secondary special
# 777714          112500.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage  Rented apartment          32            149
# 1             Civil marriage  Rented apartment          32            149
# 2             Civil marriage  Rented apartment          32            149
# 3             Civil marriage  Rented apartment          32            149
# 4             Civil marriage  Rented apartment          32            149
# ...                      ...               ...         ...            ...
# 777710  Single / not married  Rented apartment          25             39
# 777711  Single / not married  Rented apartment          25             39
# 777712  Single / not married  Rented apartment          25             39
# 777713  Single / not married  Rented apartment          25             39
# 777714  Single / not married  Rented apartment          25             39
#
#         FLAG_MOBIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE  \
# 0                1   Not Specified              2.0               0
# 1                1   Not Specified              2.0               1
# 2                1   Not Specified              2.0               2
# 3                1   Not Specified              2.0               3
# 4                1   Not Specified              2.0               4
# ...            ...             ...              ...             ...
# 777710           1        Laborers              1.0               9
# 777711           1        Laborers              1.0              10
# 777712           1        Laborers              1.0              11
# 777713           1        Laborers              1.0              12
# 777714           1        Laborers              1.0              13
#
#             STATUS
# 0             Paid
# 1             Paid
# 2             Paid
# 3             Paid
# 4             Paid
# ...            ...
# 777710  Minor Over
# 777711  Minor Over
# 777712  Minor Over
# 777713  Minor Over
# 777714  Minor Over
#
# [777715 rows x 17 columns]

# %%
#Renaming column headers
data_merge = data_merge.rename(columns={"CODE_GENDER": "Gender",
                                        "FLAG_OWN_CAR": "Owns a Car",
                                        "FLAG_OWN_REALTY": "Owns Property", 
                                        "CNT_CHILDREN": "Number of Children", 
                                        "AMT_INCOME_TOTAL": "Annual Income", 
                                        "NAME_INCOME_TYPE": "Income Category",
                                        "NAME_EDUCATION_TYPE": "Education Level",
                                        "NAME_FAMILY_STATUS": "Marital Status", 
                                        "NAME_HOUSING_TYPE": "Houseing Type", 
                                        "DAYS_BIRTH": "Age", 
                                        "DAYS_EMPLOYED": "Months Employed", 
                                        "FLAG_MOBIL": "Owns a Mobile", 
                                        "OCCUPATION_TYPE": "Occupation", 
                                        "CNT_FAM_MEMBERS": "Family Members", 
                                        "MONTHS_BALANCE": "Months Since Payment", 
                                        "STATUS": "Status"})
data_merge
# Out:
#              ID Gender Owns a Car Owns Property  Number of Children  \
# 0       5008804      M          Y             Y                   0
# 1       5008804      M          Y             Y                   0
# 2       5008804      M          Y             Y                   0
# 3       5008804      M          Y             Y                   0
# 4       5008804      M          Y             Y                   0
# ...         ...    ...        ...           ...                 ...
# 777710  5150337      M          N             Y                   0
# 777711  5150337      M          N             Y                   0
# 777712  5150337      M          N             Y                   0
# 777713  5150337      M          N             Y                   0
# 777714  5150337      M          N             Y                   0
#
#         Annual Income Income Category                Education Level  \
# 0            427500.0         Working               Higher education
# 1            427500.0         Working               Higher education
# 2            427500.0         Working               Higher education
# 3            427500.0         Working               Higher education
# 4            427500.0         Working               Higher education
# ...               ...             ...                            ...
# 777710       112500.0         Working  Secondary / secondary special
# 777711       112500.0         Working  Secondary / secondary special
# 777712       112500.0         Working  Secondary / secondary special
# 777713       112500.0         Working  Secondary / secondary special
# 777714       112500.0         Working  Secondary / secondary special
#
#               Marital Status     Houseing Type  Age  Months Employed  \
# 0             Civil marriage  Rented apartment   32              149
# 1             Civil marriage  Rented apartment   32              149
# 2             Civil marriage  Rented apartment   32              149
# 3             Civil marriage  Rented apartment   32              149
# 4             Civil marriage  Rented apartment   32              149
# ...                      ...               ...  ...              ...
# 777710  Single / not married  Rented apartment   25               39
# 777711  Single / not married  Rented apartment   25               39
# 777712  Single / not married  Rented apartment   25               39
# 777713  Single / not married  Rented apartment   25               39
# 777714  Single / not married  Rented apartment   25               39
#
#         Owns a Mobile     Occupation  Family Members  Months Since Payment  \
# 0                   1  Not Specified             2.0                     0
# 1                   1  Not Specified             2.0                     1
# 2                   1  Not Specified             2.0                     2
# 3                   1  Not Specified             2.0                     3
# 4                   1  Not Specified             2.0                     4
# ...               ...            ...             ...                   ...
# 777710              1       Laborers             1.0                     9
# 777711              1       Laborers             1.0                    10
# 777712              1       Laborers             1.0                    11
# 777713              1       Laborers             1.0                    12
# 777714              1       Laborers             1.0                    13
#
#             Status
# 0             Paid
# 1             Paid
# 2             Paid
# 3             Paid
# 4             Paid
# ...            ...
# 777710  Minor Over
# 777711  Minor Over
# 777712  Minor Over
# 777713  Minor Over
# 777714  Minor Over
#
# [777715 rows x 17 columns]

# %%
#Exporting the cleaned dataframe out as a csv
data_merge.to_csv("data_clean.csv")
