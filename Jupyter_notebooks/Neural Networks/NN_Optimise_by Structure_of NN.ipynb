# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import pandas as pd
import tensorflow as tf

# %%
# Mount the Google Drive to gain access to functions file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Access the notebook with my functions
# %run '/content/drive/My Drive/Colab Notebooks/Project_4/NN_functions.ipynb'

# %%
#  Import and read the csv file.
df=pd.read_csv("https://media.githubusercontent.com/media/DanielHughes1580/Project_4_Group_5/main/Data_Cleaned/dummied_data_add_clean.csv",index_col=0)
df.head()
# Out:
#    Number of Children  Annual Income  Age  Months Employed  Family Members  \
# 0                   0       427500.0   32             4542             2.0
# 1                   0       427500.0   32             4542             2.0
# 2                   0       427500.0   32             4542             2.0
# 3                   0       427500.0   32             4542             2.0
# 4                   0       427500.0   32             4542             2.0
#
#    Months Since Payment Status  Gender_F  Owns a Car_Y  Owns Property_Y  ...  \
# 0                     0   Paid     False          True             True  ...
# 1                     1   Paid     False          True             True  ...
# 2                     2   Paid     False          True             True  ...
# 3                     3   Paid     False          True             True  ...
# 4                     4   Paid     False          True             True  ...
#
# ...

# %%
# Call my function to encode, split and scale the data
X_train_scaled, X_test_scaled, y_train, y_test = encode_split_and_scale_data(df)

# %% [markdown]
# ## Add another layer. So have 3 hidden layers with 50 neurons in each layer

# %%
# Call the model to define, fit and evaluate the neural network model.
# This model will have 3 hidden layers with 50 neurons in each using the "relu" activation function and will train for 10 epochs
nn = define_and_fit_nn_model(X_train_scaled, X_test_scaled, y_train, y_test, 3, 50, "relu",10)
# Look at the prediction for 5 rows
nn_predict(nn,y_test,X_test_scaled)
# Out:
# Input features: 48
# Adding layer
# Adding layer
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 50)                2450
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 50)                2550
#
#  dense_3 (Dense)             (None, 3)                 153
#
# ...
# Total params: 7703 (30.09 KB)
# Trainable params: 7703 (30.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 18146/18146 [==============================] - 41s 2ms/step - loss: 0.9895 - accuracy: 0.5043
# Epoch 2/10
# 18146/18146 [==============================] - 39s 2ms/step - loss: 0.9404 - accuracy: 0.5408
# Epoch 3/10
# 18146/18146 [==============================] - 39s 2ms/step - loss: 0.9167 - accuracy: 0.5568
# Epoch 4/10
# ...

# %% [markdown]
# ## Try 3 layers with 75 neurons per layer

# %%
# Call the model to define, fit and evaluate the neural network model.
# This model will have 3 hidden layers with 75 neurons in each using the "relu" activation function and will train for 10 epochs
nn = define_and_fit_nn_model(X_train_scaled, X_test_scaled, y_train, y_test, 3, 75, "relu",10)
# Look at the prediction for 5 rows
nn_predict(nn,y_test,X_test_scaled)
# Out:
# Input features: 48
# Adding layer
# Adding layer
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 75)                3675
#
#  dense_5 (Dense)             (None, 75)                5700
#
#  dense_6 (Dense)             (None, 75)                5700
#
#  dense_7 (Dense)             (None, 3)                 228
#
# ...
# Total params: 15303 (59.78 KB)
# Trainable params: 15303 (59.78 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 18146/18146 [==============================] - 49s 3ms/step - loss: 0.9776 - accuracy: 0.5131
# Epoch 2/10
# 18146/18146 [==============================] - 48s 3ms/step - loss: 0.9163 - accuracy: 0.5568
# Epoch 3/10
# 18146/18146 [==============================] - 46s 3ms/step - loss: 0.8878 - accuracy: 0.5758
# Epoch 4/10
# ...

# %% [markdown]
# ## Try 3 layers with 100 neurons per layer

# %%
# Call the model to define, fit and evaluate the neural network model.
# This model will have 3 hidden layers with 100 neurons in each using the "relu" activation function and will train for 10 epochs
nn = define_and_fit_nn_model(X_train_scaled, X_test_scaled, y_train, y_test, 3, 100, "relu",10)
# Look at the prediction for 5 rows
nn_predict(nn,y_test,X_test_scaled)
# Out:
# Input features: 48
# Adding layer
# Adding layer
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 100)               4900
#
#  dense_9 (Dense)             (None, 100)               10100
#
#  dense_10 (Dense)            (None, 100)               10100
#
#  dense_11 (Dense)            (None, 3)                 303
#
# ...
# Total params: 25403 (99.23 KB)
# Trainable params: 25403 (99.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 18146/18146 [==============================] - 46s 2ms/step - loss: 0.9702 - accuracy: 0.5178
# Epoch 2/10
# 18146/18146 [==============================] - 44s 2ms/step - loss: 0.9006 - accuracy: 0.5692
# Epoch 3/10
# 18146/18146 [==============================] - 47s 3ms/step - loss: 0.8676 - accuracy: 0.5900
# Epoch 4/10
# ...

# %% [markdown]
# ## Try 4 layers with 100 neurons per layer

# %%
# Call the model to define, fit and evaluate the neural network model.
# This model will have 4 hidden layers with 100 neurons in each using the "relu" activation function and will train for 10 epochs
nn = define_and_fit_nn_model(X_train_scaled, X_test_scaled, y_train, y_test, 4, 100, "relu",10)
# Look at the prediction for 5 rows
nn_predict(nn,y_test,X_test_scaled)
# Out:
# Input features: 48
# Adding layer
# Adding layer
# Adding layer
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 100)               4900
#
#  dense_13 (Dense)            (None, 100)               10100
#
#  dense_14 (Dense)            (None, 100)               10100
#
#  dense_15 (Dense)            (None, 100)               10100
#
#  dense_16 (Dense)            (None, 3)                 303
#
# ...
# Total params: 35503 (138.68 KB)
# Trainable params: 35503 (138.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 18146/18146 [==============================] - 48s 3ms/step - loss: 0.9747 - accuracy: 0.5151
# Epoch 2/10
# 18146/18146 [==============================] - 149s 8ms/step - loss: 0.9007 - accuracy: 0.5677
# Epoch 3/10
# ...

# %%
# Save the model
#nn.save("NN_opt_struc_4_layers_100_neurons.h5")
# Save the model in the native Keras format
nn.save("/content/drive/My Drive/Colab Notebooks/Project_4/NN_opt_struc_4_layers_100_neurons.keras")
