# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from keras.utils import to_categorical
import pandas as pd
import tensorflow as tf

# %%
# Mount the Google Drive to gain access to functions file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Access the notebook with my functions
# %run '/content/drive/My Drive/Colab Notebooks/Project_4/NN_functions.ipynb'

# %%
#  Import and read the csv file.
df=pd.read_csv("https://media.githubusercontent.com/media/DanielHughes1580/Project_4_Group_5/main/Data_Cleaned/dummied_data_add_clean.csv",index_col=0)
df.head()
# Out:
#    Number of Children  Annual Income  Age  Months Employed  Family Members  \
# 0                   0       427500.0   32             4542             2.0
# 1                   0       427500.0   32             4542             2.0
# 2                   0       427500.0   32             4542             2.0
# 3                   0       427500.0   32             4542             2.0
# 4                   0       427500.0   32             4542             2.0
#
#    Months Since Payment Status  Gender_F  Owns a Car_Y  Owns Property_Y  ...  \
# 0                     0   Paid     False          True             True  ...
# 1                     1   Paid     False          True             True  ...
# 2                     2   Paid     False          True             True  ...
# 3                     3   Paid     False          True             True  ...
# 4                     4   Paid     False          True             True  ...
#
# ...

# %% [markdown]
# ## Optimising by reducing dimensionality

# %%
# There are two columns which have similar data - Income Category_* and Occupation_* - which both give occuption types. Try rmoving Occupation_* from the data
# to see better results are obtained.
red_df = df.drop(columns=['Occupation_Private service staff',"Occupation_Realty agents","Occupation_Sales staff","Occupation_Secretaries","Occupation_Security staff",
                          "Occupation_Waiters/barmen staff",'Occupation_Laborers','Occupation_Low-skill Laborers','Occupation_Managers','Occupation_Medicine staff',
                          'Occupation_Not Specified','Occupation_Pensioner','Occupation_Cooking staff','Occupation_Core staff','Occupation_Drivers','Occupation_HR staff',
                          'Occupation_High skill tech staff','Occupation_IT staff','Occupation_Accountants','Occupation_Cleaning staff'])

# Call my function to encode, split and scale the data
X_train_scaled, X_test_scaled, y_train, y_test = encode_split_and_scale_data(red_df)
# Call the model to define, fit and evaluate the neural network model.
# This model will have 2 hidden layers with 50 neurons in each using the "relu" activation function and will train for 10 epochs
nn = define_and_fit_nn_model(X_train_scaled, X_test_scaled, y_train, y_test, 2, 50, "relu",10)
# Look at the prediction for 5 rows
nn_predict(nn,y_test,X_test_scaled)
# Out:
# Input features: 28
# Adding layer
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 50)                1450
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 3)                 153
#
# ...
# Total params: 4153 (16.22 KB)
# Trainable params: 4153 (16.22 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 18146/18146 [==============================] - 34s 2ms/step - loss: 1.0042 - accuracy: 0.4914
# Epoch 2/10
# 18146/18146 [==============================] - 33s 2ms/step - loss: 0.9755 - accuracy: 0.5119
# Epoch 3/10
# 18146/18146 [==============================] - 32s 2ms/step - loss: 0.9601 - accuracy: 0.5241
# Epoch 4/10
# 18146/18146 [==============================] - 32s 2ms/step - loss: 0.9501 - accuracy: 0.5321
# ...

# %%
# There are two columns which have similar data - Income Category_* and Occupation_* - which both give occuption types. Now try removing Income Category_* instead from the data
# to see better results are obtained.
red_df = df.drop(columns=["Income Category_Commercial associate","Income Category_Pensioner","Income Category_State servant","Income Category_Working"])

# Call my function to encode, split and scale the data
X_train_scaled, X_test_scaled, y_train, y_test = encode_split_and_scale_data(red_df)
# Call the model to define, fit and evaluate the neural network model.
# This model will have 2 hidden layers with 50 neurons in each using the "relu" activation function and will train for 10 epochs
nn = define_and_fit_nn_model(X_train_scaled, X_test_scaled, y_train, y_test, 2, 50, "relu",10)
# Look at the prediction for 5 rows
nn_predict(nn,y_test,X_test_scaled)
# Out:
# Input features: 44
# Adding layer
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 50)                2250
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dense_5 (Dense)             (None, 3)                 153
#
# ...
# Total params: 4953 (19.35 KB)
# Trainable params: 4953 (19.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 18146/18146 [==============================] - 39s 2ms/step - loss: 0.9979 - accuracy: 0.4971
# Epoch 2/10
# 18146/18146 [==============================] - 33s 2ms/step - loss: 0.9616 - accuracy: 0.5256
# Epoch 3/10
# 18146/18146 [==============================] - 32s 2ms/step - loss: 0.9450 - accuracy: 0.5370
# Epoch 4/10
# 18146/18146 [==============================] - 33s 2ms/step - loss: 0.9345 - accuracy: 0.5452
# ...

# %%
# Try dropping the months since payment column
red_df = df.drop(columns=["Months Since Payment"])

# Call my function to encode, split and scale the data
X_train_scaled, X_test_scaled, y_train, y_test = encode_split_and_scale_data(red_df)
# Call the model to define, fit and evaluate the neural network model.
# This model will have 2 hidden layers with 50 neurons in each using the "relu" activation function and will train for 10 epochs
nn = define_and_fit_nn_model(X_train_scaled, X_test_scaled, y_train, y_test, 2, 50, "relu",10)
# Look at the prediction for 5 rows
nn_predict(nn,y_test,X_test_scaled)
# Out:
# Input features: 47
# Adding layer
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 50)                2400
#
#  dense_7 (Dense)             (None, 50)                2550
#
#  dense_8 (Dense)             (None, 3)                 153
#
# ...
# Total params: 5103 (19.93 KB)
# Trainable params: 5103 (19.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 18146/18146 [==============================] - 33s 2ms/step - loss: 1.0105 - accuracy: 0.4653
# Epoch 2/10
# 18146/18146 [==============================] - 33s 2ms/step - loss: 0.9734 - accuracy: 0.5003
# Epoch 3/10
# 18146/18146 [==============================] - 34s 2ms/step - loss: 0.9583 - accuracy: 0.5139
# Epoch 4/10
# 18146/18146 [==============================] - 32s 2ms/step - loss: 0.9492 - accuracy: 0.5225
# ...

# %%
# Try dropping the months since payment column and Income category
red_df = df.drop(columns=["Months Since Payment","Income Category_Commercial associate","Income Category_Pensioner","Income Category_State servant","Income Category_Working"])

# Call my function to encode, split and scale the data
X_train_scaled, X_test_scaled, y_train, y_test = encode_split_and_scale_data(red_df)
# Call the model to define, fit and evaluate the neural network model.
# This model will have 2 hidden layers with 50 neurons in each using the "relu" activation function and will train for 10 epochs
nn = define_and_fit_nn_model(X_train_scaled, X_test_scaled, y_train, y_test, 2, 50, "relu",10)
# Look at the prediction for 5 rows
nn_predict(nn,y_test,X_test_scaled)
# Out:
# Input features: 43
# Adding layer
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 50)                2200
#
#  dense_10 (Dense)            (None, 50)                2550
#
#  dense_11 (Dense)            (None, 3)                 153
#
# ...
# Total params: 4903 (19.15 KB)
# Trainable params: 4903 (19.15 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 18146/18146 [==============================] - 33s 2ms/step - loss: 1.0175 - accuracy: 0.4580
# Epoch 2/10
# 18146/18146 [==============================] - 33s 2ms/step - loss: 0.9822 - accuracy: 0.4927
# Epoch 3/10
# 18146/18146 [==============================] - 32s 2ms/step - loss: 0.9668 - accuracy: 0.5059
# Epoch 4/10
# 18146/18146 [==============================] - 33s 2ms/step - loss: 0.9578 - accuracy: 0.5143
# ...
